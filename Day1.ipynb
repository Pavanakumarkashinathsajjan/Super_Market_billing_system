# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "transaction_qty": [1,1,2,2,2,3,3,5,10,20,50,100]
}

df = pd.DataFrame(data)

plt.hist(df["transaction_qty"], bins=8)
plt.xlabel("Transaction Quantity")
plt.ylabel("Frequency")
plt.title("Histogram of Transaction Quantities")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "transaction_qty": [100, 120, 150, 180, 200, 250, 300, 500, 1000, 3000]
}

df = pd.DataFrame(data)

plt.hist(df["transaction_qty"], bins=10)
plt.xlabel("Transaction Quantity")
plt.ylabel("Frequency")
plt.title("Histogram of Transaction Quantities")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "transaction_qty": [10, 12, 13, 14, 15, 15, 16, 17, 18, 20]
}

df = pd.DataFrame(data)

plt.hist(df["transaction_qty"], bins=10)
plt.xlabel("Transaction Quantity")
plt.ylabel("Frequency")
plt.title("Histogram of Transaction Quantities")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 11
#       8 df = pd.DataFrame(data)
#      10 plt.hist(df["transaction_qty"], bins=10)
# ---> 11 plt.line(df['transaction_qty'])
#      12 plt.xlabel("Transaction Quantity")
#      13 plt.ylabel("Frequency")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'line'
